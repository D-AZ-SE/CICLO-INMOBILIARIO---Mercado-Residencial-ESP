# %% [markdown]
# BAJAR DATOS DEL REGISTRO DE LA PROPIEDAD DEL PAIS VASCO

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral23/opendata/2023.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.assign(Fecha='2023-03-30')
df_compraventa_2023_1 = df.iloc[:76] #primeras 70 filas
df_compraventa_2023_1.assign(Tipo='Num_compraventas')
# Out:
#                                              desglose  \
# 0                                  Nazionala/Nacional
# 1                                  Euskadi/País Vasco
# 2                             Erakunde Autonomoa/CCAA
# 3                             Erakunde Autonomoa/CCAA
# 4                             Erakunde Autonomoa/CCAA
# ..                                                ...
# 71  1.1.1.-  Etxebizitzen batez besteko prezioa (...
# 72  1.1.1.- Precio medio de vivienda (/m2). 01 tr...
# 73                                                NaN
# 74  BANATZEA                                      ...
# 75                                 Nazionala/Nacional
#
#                                            Territorio  OROKORRA GENERAL  \
# 0                                              ESPAÑA        161.024
# 1                                  EUSKADI/PAIS VASCO          6.110
# 2                                 ANDALUZIA/ANDALUCIA         32.309
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral23/opendata/2023.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.assign(Fecha='2023-06-30')
df_compraventa_2023_2 = df.iloc[:76] #primeras 70 filas
df_compraventa_2023_2.assign(Tipo='Num_compraventas')
# Out:
#                                              desglose  \
# 0                                  Nazionala/Nacional
# 1                                  Euskadi/País Vasco
# 2                             Erakunde Autonomoa/CCAA
# 3                             Erakunde Autonomoa/CCAA
# 4                             Erakunde Autonomoa/CCAA
# ..                                                ...
# 71  1.1.1.-  Etxebizitzen batez besteko prezioa (...
# 72  1.1.1.- Precio medio de vivienda (/m2). 02 tr...
# 73                                                NaN
# 74  BANATZEA                                      ...
# 75                                 Nazionala/Nacional
#
#                                            Territorio  OROKORRA GENERAL  \
# 0                                              ESPAÑA            151983
# 1                                  EUSKADI/PAIS VASCO              5038
# 2                                 ANDALUZIA/ANDALUCIA             30698
# ...

# %%
df_compraventa_tot = pd.concat([df_compraventa_2023_1 , df_compraventa_2023_2 ])
print(df_compraventa_tot)
# Out:
#                                              desglose  \
# 0                                  Nazionala/Nacional
# 1                                  Euskadi/País Vasco
# 2                             Erakunde Autonomoa/CCAA
# 3                             Erakunde Autonomoa/CCAA
# 4                             Erakunde Autonomoa/CCAA
# ..                                                ...
# 71  1.1.1.-  Etxebizitzen batez besteko prezioa (...
# 72  1.1.1.- Precio medio de vivienda (/m2). 02 tr...
# 73                                                NaN
# 74  BANATZEA                                      ...
# 75                                 Nazionala/Nacional
#
#                                            Territorio  OROKORRA GENERAL  \
# 0                                              ESPAÑA        161.024
# 1                                  EUSKADI/PAIS VASCO          6.110
# 2                                 ANDALUZIA/ANDALUCIA         32.309
# ...

# %%
df_compraventa_tot
# Out:
#                                              desglose  \
# 0                                  Nazionala/Nacional
# 1                                  Euskadi/País Vasco
# 2                             Erakunde Autonomoa/CCAA
# 3                             Erakunde Autonomoa/CCAA
# 4                             Erakunde Autonomoa/CCAA
# ..                                                ...
# 71  1.1.1.-  Etxebizitzen batez besteko prezioa (...
# 72  1.1.1.- Precio medio de vivienda (/m2). 02 tr...
# 73                                                NaN
# 74  BANATZEA                                      ...
# 75                                 Nazionala/Nacional
#
#                                            Territorio  OROKORRA GENERAL  \
# 0                                              ESPAÑA        161.024
# 1                                  EUSKADI/PAIS VASCO          6.110
# 2                                 ANDALUZIA/ANDALUCIA         32.309
# ...

# %%
df_compraventa_tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 75
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   desglose          146 non-null    object
#  1   Territorio        142 non-null    object
#  2   OROKORRA GENERAL  142 non-null    object
#  3   BERRIA NUEVA      142 non-null    object
#  4   ERABILIA USADA    142 non-null    object
#  5   Fecha             152 non-null    object
# dtypes: object(6)
# memory usage: 8.3+ KB

# %%
df_compraventa_2023_1 = df.iloc[:76] #primeras 70 filas
df_compraventa_2023_1  = df.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral23/opendata/2023.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.assign(Fecha='2023-06-30')
#print(df)
df_compraventa_2023_2 = df.iloc[:76] #primeras 70 filas
df_compraventa_2023_2  = df.assign(Tipo='Num_compraventas')
df_compraventa_tot = pd.concat([df_compraventa_2023_1 , df_compraventa_2023_2 ])
print(df_compraventa_tot)
# Out:
#                     desglose           Territorio OROKORRA GENERAL  \
# 0         Nazionala/Nacional               ESPAÑA           151983
# 1         Euskadi/País Vasco   EUSKADI/PAIS VASCO             5038
# 2    Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA            30698
# 3    Erakunde Autonomoa/CCAA        ARAGOI/ARAGON             3966
# 4    Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS             3145
# ..                       ...                  ...              ...
# 814                      NaN                  NaN             2,71
# 815                      NaN                  NaN             2,62
# 816                      NaN                  NaN              NaN
# 817                      NaN                  NaN              NaN
# 818                      NaN                  NaN              NaN
#
#     BERRIA NUEVA ERABILIA USADA       Fecha              Tipo  \
# 0          28739         123244  2023-06-30  Num_compraventas
# ...

# %% [markdown]
# VAMOS A EMPREZAR DESDE EL PRINCIPIO CON LOS LISTADOS DE COMPRAVENTAS

# %%
import pandas as pd

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral23/opendata/2023.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2023-06-30')
df_compraventa_2023_2 = df.iloc[:70] #primeras 70 filas
df_compraventa_2023_2.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA       151983
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO         5038
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA        30698
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON         3966
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS         3145
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri           73
# 66  Udalerriak >40.000/Municipios >40.000                Getxo          182
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete           69
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi          113
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
import pandas as pd

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral23/opendata/2023.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2023-03-30')
df_compraventa_2023_1 = df.iloc[:70] #primeras 70 filas
df_compraventa_2023_1.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA   161.024
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO     6.110
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    32.309
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     3.952
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     3.141
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri        65
# 66  Udalerriak >40.000/Municipios >40.000                Getxo       154
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete       112
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi       165
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
frames = [df_compraventa_2023_2, df_compraventa_2023_1]  
df_compraventa_2023 = pd.concat(frames, ignore_index=True)
df_compraventa_2023.assign(Tipo='Num_compraventas')
# Out:
#                                   Desglose           Territorio Viv. GENERAL  \
# 0                       Nazionala/Nacional               ESPAÑA       151983
# 1                       Euskadi/País Vasco   EUSKADI/PAIS VASCO         5038
# 2                  Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA        30698
# 3                  Erakunde Autonomoa/CCAA        ARAGOI/ARAGON         3966
# 4                  Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS         3145
# ..                                     ...                  ...          ...
# 135  Udalerriak >40.000/Municipios >40.000              Basauri        65
# 136  Udalerriak >40.000/Municipios >40.000                Getxo       154
# 137  Udalerriak >40.000/Municipios >40.000          Portugalete       112
# 138  Udalerriak >40.000/Municipios >40.000            Santurtzi       165
# 139                                    NaN                  NaN          NaN
#
#     Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral22/opendata/2022.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2022-12-30')
df_compraventa_2022_4 = df.iloc[:70] #primeras 70 filas
df_compraventa_2022_4.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA       150141
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO         5125
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA        31472
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON         3551
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS         2726
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri           72
# 66  Udalerriak >40.000/Municipios >40.000                Getxo          173
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete           90
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi          147
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral22/opendata/2022.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2022-09-30')
df_compraventa_2022_3 = df.iloc[:70] #primeras 70 filas
df_compraventa_2022_3.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA       167892
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO         5967
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA        34608
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON         4572
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS         2867
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri           81
# 66  Udalerriak >40.000/Municipios >40.000                Getxo          281
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete           92
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi          129
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral22/opendata/ER_2022_2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2022-06-30')
df_compraventa_2022_2 = df.iloc[:70] #primeras 70 filas
df_compraventa_2022_2.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA      163.909
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO        6.160
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA       33.186
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON        4.410
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS        2.950
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri          111
# 66  Udalerriak >40.000/Municipios >40.000                Getxo          160
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete          120
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi          182
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral22/opendata/ER_2022_1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2022-03-30')
df_compraventa_2022_1 = df.iloc[:70] #primeras 70 filas
df_compraventa_2022_1.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA       164299
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO         6371
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA        34215
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON         4136
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS         2851
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri          140
# 66  Udalerriak >40.000/Municipios >40.000                Getxo          184
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete           65
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi           91
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
frames = [df_compraventa_2022_4, df_compraventa_2022_3, df_compraventa_2022_2, df_compraventa_2022_1]  
df_compraventa_2022 = pd.concat(frames, ignore_index=True)
df_compraventa_2022.assign(Tipo='Num_compraventas')
# Out:
#                                   Desglose           Territorio Viv. GENERAL  \
# 0                       Nazionala/Nacional               ESPAÑA       150141
# 1                       Euskadi/País Vasco   EUSKADI/PAIS VASCO         5125
# 2                  Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA        31472
# 3                  Erakunde Autonomoa/CCAA        ARAGOI/ARAGON         3551
# 4                  Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS         2726
# ..                                     ...                  ...          ...
# 275  Udalerriak >40.000/Municipios >40.000              Basauri          140
# 276  Udalerriak >40.000/Municipios >40.000                Getxo          184
# 277  Udalerriak >40.000/Municipios >40.000          Portugalete           65
# 278  Udalerriak >40.000/Municipios >40.000            Santurtzi           91
# 279                                    NaN                  NaN          NaN
#
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral21/opendata/2021.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2021-12-30')
df_compraventa_2021_4 = df.iloc[:70] #primeras 70 filas
df_compraventa_2021_4.assign(Tipo='Num_compraventas')
# Out:
#                                  Desglose           Territorio Viv. GENERAL  \
# 0                      Nazionala/Nacional               ESPAÑA   143.982
# 1                      Euskadi/País Vasco   EUSKADI/PAIS VASCO     4.803
# 2                 Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    31.325
# 3                 Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     3.508
# 4                 Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     2.388
# ..                                    ...                  ...          ...
# 65  Udalerriak >40.000/Municipios >40.000              Basauri       108
# 66  Udalerriak >40.000/Municipios >40.000                Getxo       152
# 67  Udalerriak >40.000/Municipios >40.000          Portugalete        57
# 68  Udalerriak >40.000/Municipios >40.000            Santurtzi        84
# 69                                    NaN                  NaN          NaN
#
#    Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral21/opendata/2021.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2021-09-30')
df_compraventa_2021_3 = df.iloc[:60] #primeras x filas
df_compraventa_2021_3.assign(Tipo='Num_compraventas')
# Out:
#                                   Desglose                         Territorio  \
# 0                       Nazionala/Nacional                             ESPAÑA
# 1                       Euskadi/País Vasco                 EUSKADI/PAIS VASCO
# 2                  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA
# 3                  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON
# 4                  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS
# 5                  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES
# 6                  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS
# 7                  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA
# 8                  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON
# 9                  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA
# 10                 Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral21/opendata/Estadistica-Registradores-2021.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2021-06-30')
df_compraventa_2021_2 = df.iloc[:60] #primeras x filas
df_compraventa_2021_2.assign(Tipo='Num_compraventas')
# Out:
#                                   Desglose                         Territorio  \
# 0                       Nazionala/Nacional                             ESPAÑA
# 1                       Euskadi/País Vasco                 EUSKADI/PAIS VASCO
# 2                  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA
# 3                  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON
# 4                  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS
# 5                  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES
# 6                  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS
# 7                  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA
# 8                  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON
# 9                  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA
# 10                 Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral21/opendata/Estadistica-Registradores-2021.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2021-03-30')
df_compraventa_2021_1 = df.iloc[:60] #primeras x filas
df_compraventa_2021_1.assign(Tipo='Num_compraventas')
# Out:
#                                   Desglose                         Territorio  \
# 0                       Nazionala/Nacional                             ESPAÑA
# 1                       Euskadi/País Vasco                 EUSKADI/PAIS VASCO
# 2                  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA
# 3                  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON
# 4                  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS
# 5                  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES
# 6                  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS
# 7                  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA
# 8                  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON
# 9                  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA
# 10                 Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA
# ...

# %%
frames = [df_compraventa_2021_4, df_compraventa_2021_3, df_compraventa_2021_2, df_compraventa_2021_1]  
df_compraventa_2021 = pd.concat(frames, ignore_index=True)
df_compraventa_2021.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA   143.982
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     4.803
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    31.325
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     3.508
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     2.388
# ..                                      ...                  ...          ...
# 245  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05       125
# 246  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06       131
# 247  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07       141
# 248  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        61
# 249                                     NaN                  NaN          NaN
#
# ...

# %%
df_compraventa_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Desglose            246 non-null    object
#  1   Territorio          246 non-null    object
#  2   Viv. GENERAL        187 non-null    object
#  3   Viv. NUEVA          187 non-null    object
#  4   Viv. USADA          187 non-null    object
#  5   Fecha               250 non-null    object
#  6    OROKORRA GENERAL   59 non-null     object
#  7    BERRIA NUEVA       59 non-null     object
#  8    ERABILIA USADA     59 non-null     object
# dtypes: object(9)
# memory usage: 17.7+ KB

# %%
# observo que en el dataset combinado, aparecen unas columnas vacias que habria que suprimir
df_compraventa_2021.drop(columns=[' OROKORRA GENERAL',' BERRIA NUEVA',' ERABILIA USADA'], inplace=True)
df_compraventa_2021
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\PERSONAL-DAS\BOOTCAMP\Carpeta-VISUAL\CURSO\Alumno-DAS\2-Data_Analysis\Z-Entregas\2_EDA\Estadistica registral.ipynb Cell 23 line 2
#       <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # observo que en el dataset combinado, aparecen unas columnas vacias que habria que suprimir
# ----> <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> df_compraventa_2021.drop(columns=[' OROKORRA GENERAL',' BERRIA NUEVA',' ERABILIA USADA'], inplace=True)
# ...

# %%
df_compraventa_2021.drop('OROKORRA GENERAL', axis=1, inplace=True)
df_compraventa_2021
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\PERSONAL-DAS\BOOTCAMP\Carpeta-VISUAL\CURSO\Alumno-DAS\2-Data_Analysis\Z-Entregas\2_EDA\Estadistica registral.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> df_compraventa_2021.drop('OROKORRA GENERAL', axis=1, inplace=True)
#       <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#Y121sZmlsZQ%3D%3D?line=1'>2</a> df_compraventa_2021
#
# File d:\Programas\Phyton\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
# ...

# %%
# observo que en el dataset combinado, aparecen unas columnas vacias que habria que suprimir
# df_compraventa_2021.drop(columns=[7,8,9], axis=1)
# df_compraventa_2021

# %%
import pandas as pd
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral20/opendata/ER-2020.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-12-30')
df_compraventa_2020_4 = df.iloc[:60] #primeras 70 filas
df_compraventa_2020_4.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral20/opendata/2020.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-09-30')
df_compraventa_2020_3 = df.iloc[:60] #primeras 70 filas
df_compraventa_2020_3.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral20/opendata/2020.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-06-30')
df_compraventa_2020_2 = df.iloc[:60] #primeras 70 filas
df_compraventa_2020_2.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral20/opendata/2020.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras cinco columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-03-30')
df_compraventa_2020_1 = df.iloc[:60] #primeras 70 filas
df_compraventa_2020_1.assign(Tipo='Num_compraventas')
# Out:
#                                   Desglose  \
# 0                       Nazionala/Nacional
# 1                       Euskadi/País Vasco
# 2                  Erakunde Autonomoa/CCAA
# 3                  Erakunde Autonomoa/CCAA
# 4                  Erakunde Autonomoa/CCAA
# 5                  Erakunde Autonomoa/CCAA
# 6                  Erakunde Autonomoa/CCAA
# 7                  Erakunde Autonomoa/CCAA
# 8                  Erakunde Autonomoa/CCAA
# 9                  Erakunde Autonomoa/CCAA
# 10                 Erakunde Autonomoa/CCAA
# 11                 Erakunde Autonomoa/CCAA
# 12                 Erakunde Autonomoa/CCAA
# 13                 Erakunde Autonomoa/CCAA
# 14                 Erakunde Autonomoa/CCAA
# 15                 Erakunde Autonomoa/CCAA
# 16                 Erakunde Autonomoa/CCAA
# 17                 Erakunde Autonomoa/CCAA
# 18             Hiriburak/Capitales de TTHH
# 19             Hiriburak/Capitales de TTHH
# 20             Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_compraventa_2020_4, df_compraventa_2020_3, df_compraventa_2020_2, df_compraventa_2020_1]  
df_compraventa_2020 = pd.concat(frames, ignore_index=True)
df_compraventa_2020.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA   113.799
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     4.361
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    22.770
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     3.353
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     2.276
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales                  NaN    2.183,99
# 236  Hiriburuetako zonak/Zonas de capitales                  NaN    3.780,81
# 237  Hiriburuetako zonak/Zonas de capitales                  NaN    2.449,40
# 238  Hiriburuetako zonak/Zonas de capitales                  NaN    2.240,58
# 239                                     NaN                  NaN          NaN
#
#     Viv. NUEVA  Viv. USADA       Fecha  \
# ...

# %%
# En este datasat combinado, vuelve a ser necesario modificar columnas 'EREMUA ÁMBITO', 'BERRIA NUEVA'
df_compraventa_2020.loc[: ,['Desglose', 'Territorio', 'Viv. GENERAL', 'Viv. NUEVA', 'Viv. USADA', 'Fecha', 'Tipo']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\PERSONAL-DAS\BOOTCAMP\Carpeta-VISUAL\CURSO\Alumno-DAS\2-Data_Analysis\Z-Entregas\2_EDA\Estadistica registral.ipynb Cell 29 line 2
#       <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> # En este datasat combinado, vuelve a ser necesario modificar columnas 'EREMUA ÁMBITO', 'BERRIA NUEVA'
# ----> <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a> df_compraventa_2020.loc[: ,['Desglose', 'Territorio', 'Viv. GENERAL', 'Viv. NUEVA', 'Viv. USADA', 'Fecha', 'Tipo']]
#
# ...

# %%
import pandas as pd
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral19/opendata/2019.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-12-30')
df_compraventa_2019_4 = df.iloc[:60] #primeras x filas
df_compraventa_2019_4.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral19/opendata/2019.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-09-30')
df_compraventa_2019_3 = df.iloc[:60] #primeras x filas
df_compraventa_2019_3.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral19/opendata/2019.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-06-30')
df_compraventa_2019_2 = df.iloc[:60] #primeras x filas
df_compraventa_2019_2.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral19/opendata/2019.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-03-30')
df_compraventa_2019_1 = df.iloc[:60] #primeras x filas
df_compraventa_2019_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2019_4, df_compraventa_2019_3, df_compraventa_2019_2, df_compraventa_2019_1]  
df_compraventa_2019 = pd.concat(frames, ignore_index=True)
df_compraventa_2019.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA      117.387
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO        4.608
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA       24.030
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON        3.366
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS        1.894
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05       231
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06       161
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07       207
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        59
# 239                                     NaN                  NaN          NaN
#
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral18/opendata/2018.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2018-12-30')
df_compraventa_2018_4 = df.iloc[:60] #primeras x filas
df_compraventa_2018_4.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral18/opendata/2018.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-09-30')
df_compraventa_2018_3 = df.iloc[:60] # primeras x filas
df_compraventa_2018_3.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral18/opendata/2018.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2018-06-30')
df_compraventa_2018_2 = df.iloc[:60] # primeras x filas
df_compraventa_2018_2.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral18/opendata/2018.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2018-03-30')
df_compraventa_2018_1 = df.iloc[:60] #primeras x filas
df_compraventa_2018_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2018_4, df_compraventa_2018_3, df_compraventa_2018_2, df_compraventa_2018_1]  
df_compraventa_2018 = pd.concat(frames, ignore_index=True)
df_compraventa_2018.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA   120.199
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     4.398
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    23.850
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     3.131
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     2.065
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05       156
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06       129
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07       119
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        45
# 239                                     NaN                  NaN          NaN
#
#     Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df_compraventa_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral17/opendata/2017.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-12-30')
df_compraventa_2017_4 = df.iloc[:60] #primeras x filas
df_compraventa_2017_4.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral17/opendata/2017.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-09-30')
df_compraventa_2017_3 = df.iloc[:60] #primeras x filas
df_compraventa_2017_3.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral17/opendata/2017.2.csv',sep=';',encoding='latin-1',skiprows=2)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-06-30')
df_compraventa_2017_2 = df.iloc[:59] #primeras x filas
df_compraventa_2017_2.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral17/opendata/2017.1.csv',sep=';',encoding='latin-1',skiprows=2)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-03-30')
df_compraventa_2017_1 = df.iloc[:59] #primeras x filas
df_compraventa_2017_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2017_4, df_compraventa_2017_3, df_compraventa_2017_2, df_compraventa_2017_1]  
df_compraventa_2017 = pd.concat(frames, ignore_index=True)
df_compraventa_2017.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA   111.921
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     3.893
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    22.045
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     3.148
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     2.004
# ..                                      ...                  ...          ...
# 233  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 04        83
# 234  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05       150
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06       175
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07       156
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        43
#
#     Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral16/opendata/2016.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-12-30')
df_compraventa_2016_4 = df.iloc[:60] #primeras x filas
df_compraventa_2016_4.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral16/opendata/2016.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-09-30')
df_compraventa_2016_3 = df.iloc[:60] #primeras x filas
df_compraventa_2016_3.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral16/opendata/2016.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-06-30')
df_compraventa_2016_2 = df.iloc[:60] #primeras x filas
df_compraventa_2016_2.assign(Tipo='Num_compraventas')

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral16/opendata/2016.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-03-30')
df_compraventa_2016_1 = df.iloc[:60] #primeras x filas
df_compraventa_2016_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2016_4, df_compraventa_2016_3, df_compraventa_2016_2, df_compraventa_2016_1]  
df_compraventa_2016 = pd.concat(frames, ignore_index=True)
df_compraventa_2016.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA    93.423
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     3.450
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    18.149
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     2.514
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     1.613
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05          219
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06          159
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07          108
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08           34
# 239                                     NaN                  NaN          NaN
#
# ...

# %%
df_compraventa_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral15/es_def/adjuntos/2015.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-12-30')
df_compraventa_2015_4 = df.iloc[:60] #primeras x filas
df_compraventa_2015_4.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral15/es_def/adjuntos/2015.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-09-30')
df_compraventa_2015_3 = df.iloc[:60] #primeras x filas
df_compraventa_2015_3.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral15/es_def/adjuntos/2015.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-06-30')
df_compraventa_2015_2 = df.iloc[:60] #primeras x filas
df_compraventa_2015_2.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral15/es_def/adjuntos/2015.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-03-30')
df_compraventa_2015_1 = df.iloc[:60] #primeras x filas
df_compraventa_2015_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2015_4, df_compraventa_2015_3, df_compraventa_2015_2, df_compraventa_2015_1]  
df_compraventa_2015 = pd.concat(frames, ignore_index=True)
df_compraventa_2015.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA       84.031
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO        3.366
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA       16.535
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON        2.194
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS        1.439
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05       110
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06        87
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07       136
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        30
# 239                                     NaN                  NaN          NaN
#
# ...

# %%
df_compraventa_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral14/es_def/adjuntos/2014.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-12-30')
df_compraventa_2014_4 = df.iloc[:60] #primeras x filas
df_compraventa_2014_4.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral14/es_def/adjuntos/2014.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-09-30')
df_compraventa_2014_3 = df.iloc[:60] #primeras x filas
df_compraventa_2014_3.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral14/es_def/adjuntos/2014.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-06-30')
df_compraventa_2014_2 = df.iloc[:60] #primeras x filas
df_compraventa_2014_2.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral14/es_def/adjuntos/2014.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-03-30')
df_compraventa_2014_1 = df.iloc[:60] #primeras x filas
df_compraventa_2014_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2014_4, df_compraventa_2014_3, df_compraventa_2014_2, df_compraventa_2014_1]  
df_compraventa_2014 = pd.concat(frames, ignore_index=True)
df_compraventa_2014.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA    77.881
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     2.805
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    15.800
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     2.115
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     1.275
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05        84
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06       119
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07        96
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        26
# 239                                     NaN                  NaN          NaN
#
#     Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df_compraventa_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral13/es_def/adjuntos/2013.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-12-30')
df_compraventa_2013_4 = df.iloc[:60] #primeras x filas
df_compraventa_2013_4.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral13/es_def/adjuntos/2013.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-09-30')
df_compraventa_2013_3 = df.iloc[:60] #primeras x filas
df_compraventa_2013_3.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral13/es_def/adjuntos/2013.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-06-30')
df_compraventa_2013_2 = df.iloc[:60] #primeras x filas
df_compraventa_2013_2.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral13/es_def/adjuntos/2013.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-03-30')
df_compraventa_2013_1 = df.iloc[:60] #primeras x filas
df_compraventa_2013_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2013_4, df_compraventa_2013_3, df_compraventa_2013_2, df_compraventa_2013_1]  
df_compraventa_2013 = pd.concat(frames, ignore_index=True)
df_compraventa_2013.assign(Tipo='Num_compraventas')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA    72.560
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO     2.157
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    14.592
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON     1.863
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS     1.248
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05        83
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06        91
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07        84
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08        19
# 239                                     NaN                  NaN          NaN
#
#     Viv. NUEVA Viv. USADA       Fecha              Tipo
# ...

# %%
df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral12/es_def/adjuntos/2012.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-12-30')
df_compraventa_2012_4 = df.iloc[:60] #primeras x filas
df_compraventa_2012_4.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral12/es_def/adjuntos/2012.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-09-30')
df_compraventa_2012_3 = df.iloc[:60] #primeras x filas
df_compraventa_2012_3.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral12/es_def/adjuntos/2012.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-06-30')
df_compraventa_2012_2 = df.iloc[:60] #primeras x filas
df_compraventa_2012_2.assign(Tipo='Num_compraventas')

df = pd.read_csv('https://www.euskadi.eus/contenidos/estadistica/ovv_registral12/es_def/adjuntos/2012.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-03-30')
df_compraventa_2012_1 = df.iloc[:60] #primeras x filas
df_compraventa_2012_1.assign(Tipo='Num_compraventas')

# %%
frames = [df_compraventa_2012_4, df_compraventa_2012_3, df_compraventa_2012_2, df_compraventa_2012_1]  
df_compraventa_2012 = pd.concat(frames, ignore_index=True)
df_compraventa_2012.assign(Tipo='Num_compraventas')
# Out:
#                                     Desglose           Territorio  \
# 0                         Nazionala/Nacional               ESPAÑA
# 1                         Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                    Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                    Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                    Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                       ...                  ...
# 235  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
# 239                                      NaN                  NaN
#
#     Viv. GENERAL Viv. NUEVA Viv. USADA       Fecha              Tipo
# 0      78.281       38.572     39.709   2012-12-30  Num_compraventas
# ...

# %%
df_compraventa_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
frames = [df_compraventa_2023, df_compraventa_2022, df_compraventa_2021, df_compraventa_2020, df_compraventa_2019, df_compraventa_2018, df_compraventa_2017, df_compraventa_2016, df_compraventa_2015, df_compraventa_2014, df_compraventa_2013, df_compraventa_2012]  
df_compraventa = pd.concat(frames, ignore_index=True)
df_compraventa.assign(Tipo='Num_compraventas')
# Out:
#                                      Desglose           Territorio  \
# 0                          Nazionala/Nacional               ESPAÑA
# 1                          Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                     Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                     Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                     Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ...                                       ...                  ...
# 3174  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 3175  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 3176  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 3177  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
# 3178                                      NaN                  NaN
#
#      Viv. GENERAL Viv. NUEVA Viv. USADA       Fecha  OROKORRA GENERAL   \
# 0          151983      28739     123244  2023-06-30                NaN
# ...

# %%
df_compraventa.drop(columns=['OROKORRA GENERAL'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\PERSONAL-DAS\BOOTCAMP\Carpeta-VISUAL\CURSO\Alumno-DAS\2-Data_Analysis\Z-Entregas\2_EDA\Estadistica registral.ipynb Cell 64 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/Estadistica%20registral.ipynb#Y130sZmlsZQ%3D%3D?line=0'>1</a> df_compraventa.drop(columns=['OROKORRA GENERAL'], inplace=True)
#
# File d:\Programas\Phyton\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
# ...
