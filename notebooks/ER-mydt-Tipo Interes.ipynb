# %% [markdown]
# VAMOS A EMPREZAR DESDE EL PRINCIPIO CON LOS LISTADOS: TIPO DE INTERES

# %%
import pandas as pd


df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2023.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2023-06-30')
df_tipo_interes_2023_2 = df.iloc[795:816] #primeras x filas
df_tipo_interes_2023_2.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 795       Nazionala/Nacional                             ESPAÑA      3,37
# 796       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      2,65
# 797  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      3,47
# 798  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON       3,2
# 799  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      3,37
# 800  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      3,47
# 801  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      3,64
# 802  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      3,27
# 803  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON       3,2
# 804  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      3,47
# 805  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      3,53
# 806  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA       3,2
# ...

# %%
import pandas as pd

df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2023.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2023-03-30')
df_tipo_interes_2023_1 = df.iloc[794:815] #primeras x filas
df_tipo_interes_2023_1.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 794       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      2,54
# 795  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      3,13
# 796  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      2,96
# 797  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      3,09
# 798  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      3,16
# 799  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      3,34
# 800  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      3,03
# 801  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      2,99
# 802  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      3,24
# 803  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      3,20
# 804  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      3,00
# 805  Erakunde Autonomoa/CCAA                    GALIZIA/GALICIA      3,19
# ...

# %%
frames = [df_tipo_interes_2023_2, df_tipo_interes_2023_1]  
df_tipo_interes_2023 = pd.concat(frames, ignore_index=True)
df_tipo_interes_2023.assign(Tipo='Tipo de Interes')
# Out:
#                    Desglose                         Territorio T.Interes  \
# 0        Nazionala/Nacional                             ESPAÑA      3,37
# 1        Euskadi/País Vasco                 EUSKADI/PAIS VASCO      2,65
# 2   Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      3,47
# 3   Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON       3,2
# 4   Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      3,37
# 5   Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      3,47
# 6   Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      3,64
# 7   Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      3,27
# 8   Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON       3,2
# 9   Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      3,47
# 10  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      3,53
# 11  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA       3,2
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2022.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-12-30')
df_tipo_interes_2022_4 = df.iloc[772:793] #primeras x filas
df_tipo_interes_2022_4.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 772       Nazionala/Nacional                             ESPAÑA      2,55
# 773       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      2,19
# 774  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      2,51
# 775  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      2,45
# 776  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      2,61
# 777  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      2,92
# 778  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      2,67
# 779  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      2,44
# 780  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      2,54
# 781  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      2,61
# 782  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA       2,6
# 783  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      2,63
# ...

# %%
# df = pd.read_csv('Data/2022.3.csv')

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2022.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-09-30')
df_tipo_interes_2022_3 = df.iloc[798:819] #primeras x filas
df_tipo_interes_2022_3.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 798       Nazionala/Nacional                             ESPAÑA      2,23
# 799       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      1,88
# 800  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      2,21
# 801  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      2,21
# 802  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      2,47
# 803  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES       2,2
# 804  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      2,45
# 805  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      2,11
# 806  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      2,14
# 807  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      2,32
# 808  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      2,27
# 809  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      2,34
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2022.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-06-30')
df_tipo_interes_2022_2 = df.iloc[796:817] #primeras x filas
df_tipo_interes_2022_2.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 796       Nazionala/Nacional                             ESPAÑA      2,15
# 797       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      1,77
# 798  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA       2,2
# 799  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      2,24
# 800  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      2,21
# 801  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      2,09
# 802  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      2,28
# 803  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      2,05
# 804  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      2,08
# 805  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      2,26
# 806  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      2,18
# 807  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      2,43
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2022.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-03-30')
df_tipo_interes_2022_1 = df.iloc[797:818] #primeras x filas
df_tipo_interes_2022_1.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 797       Nazionala/Nacional                             ESPAÑA      1,86
# 798       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      1,39
# 799  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      1,92
# 800  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      1,91
# 801  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      1,96
# 802  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      1,85
# 803  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      2,12
# 804  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      1,73
# 805  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      1,88
# 806  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      2,03
# 807  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      1,89
# 808  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      2,14
# ...

# %%
frames = [df_tipo_interes_2022_4, df_tipo_interes_2022_3, df_tipo_interes_2022_2, df_tipo_interes_2022_1]  
df_tipo_interes_2022 = pd.concat(frames, ignore_index=True)
df_tipo_interes_2022.assign(Tipo='Tipo de Interes')
# Out:
#                    Desglose                      Territorio T.Interes  \
# 0        Nazionala/Nacional                          ESPAÑA      2,55
# 1        Euskadi/País Vasco              EUSKADI/PAIS VASCO      2,19
# 2   Erakunde Autonomoa/CCAA             ANDALUZIA/ANDALUCIA      2,51
# 3   Erakunde Autonomoa/CCAA                   ARAGOI/ARAGON      2,45
# 4   Erakunde Autonomoa/CCAA               ASTURIAS/ASTURIAS      2,61
# ..                      ...                             ...       ...
# 79  Erakunde Autonomoa/CCAA                ERRIOXA/LA RIOJA      1,87
# 80  Erakunde Autonomoa/CCAA  VALENTZIA KOMUNITATEA/VALENCIA      1,98
# 81           Lurraldea/TTHH                     ARABA/ÁLAVA      1,54
# 82           Lurraldea/TTHH                        GIPUZKOA      1,41
# 83           Lurraldea/TTHH                         BIZKAIA      1,33
#
#          Fecha             Tipo
# 0   2022-12-30  Tipo de Interes
# 1   2022-12-30  Tipo de Interes
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2021.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-12-30')
df_tipo_interes_2021_4 = df.iloc[778:799] #primeras x filas
df_tipo_interes_2021_4.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 778       Nazionala/Nacional                             ESPAÑA     1,92
# 779       Euskadi/País Vasco                 EUSKADI/PAIS VASCO     1,48
# 780  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA     1,93
# 781  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON     1,95
# 782  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS     2,14
# 783  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES     1,89
# 784  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS     2,04
# 785  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA     1,75
# 786  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON     1,92
# 787  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA     2,15
# 788  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA     1,99
# 789  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA     2,19
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2021.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-09-30')
df_tipo_interes_2021_3 = df.iloc[663:684] #primeras x filas
df_tipo_interes_2021_3.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 663       Nazionala/Nacional                             ESPAÑA      1,94
# 664       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      1,41
# 665  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      1,97
# 666  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      1,97
# 667  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      2,07
# 668  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES         2
# 669  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      2,11
# 670  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      1,83
# 671  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      1,91
# 672  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      2,09
# 673  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      2,01
# 674  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      2,17
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2021.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-06-30')
df_tipo_interes_2021_2 = df.iloc[693:714] #primeras x filas
df_tipo_interes_2021_2.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 693       Nazionala/Nacional                             ESPAÑA      2,02
# 694       Euskadi/País Vasco                 EUSKADI/PAIS VASCO      1,49
# 695  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA      2,04
# 696  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON      2,14
# 697  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS      2,03
# 698  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES      2,10
# 699  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS      2,06
# 700  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA      1,93
# 701  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON      2,00
# 702  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA      2,23
# 703  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA      2,09
# 704  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA      2,26
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2021.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:3] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio','INTERESA     INTERES':'T.Interes'})
df = df.rename(columns={'OROKORRA GENERAL': "T.Interes"})
df = df.assign(Fecha='2022-03-30')
df_tipo_interes_2021_1 = df.iloc[728:749] #primeras x filas
df_tipo_interes_2021_1.assign(Tipo='Tipo de Interes')
# Out:
#                     Desglose                         Territorio T.Interes  \
# 728       Nazionala/Nacional                             ESPAÑA   2,10
# 729       Euskadi/País Vasco                 EUSKADI/PAIS VASCO   1,53
# 730  Erakunde Autonomoa/CCAA                ANDALUZIA/ANDALUCIA   2,19
# 731  Erakunde Autonomoa/CCAA                      ARAGOI/ARAGON   2,20
# 732  Erakunde Autonomoa/CCAA                  ASTURIAS/ASTURIAS   2,06
# 733  Erakunde Autonomoa/CCAA           BALEAR UHARTEAK/BALEARES   2,14
# 734  Erakunde Autonomoa/CCAA         KANARIAR UHARTEAK/CANARIAS   2,42
# 735  Erakunde Autonomoa/CCAA                KANTABRIA/CANTABRIA   2,01
# 736  Erakunde Autonomoa/CCAA   GAZTELA ETA LEON/CASTILLA Y LEON   2,05
# 737  Erakunde Autonomoa/CCAA  GAZTELA-MANTXA/CASTILLA-LA MANCHA   2,28
# 738  Erakunde Autonomoa/CCAA                 KATALUNIA/CATALUÑA   2,18
# 739  Erakunde Autonomoa/CCAA            EXTREMADURA/EXTREMADURA   2,26
# ...

# %%
frames = [df_tipo_interes_2021_4, df_tipo_interes_2021_3, df_tipo_interes_2021_2, df_tipo_interes_2021_1]  
df_tipo_interes_2021 = pd.concat(frames, ignore_index=True)
df_tipo_interes_2021.assign(Tipo='Tipo de Interes')
# Out:
#                    Desglose                      Territorio T.Interes  \
# 0        Nazionala/Nacional                          ESPAÑA     1,92
# 1        Euskadi/País Vasco              EUSKADI/PAIS VASCO     1,48
# 2   Erakunde Autonomoa/CCAA             ANDALUZIA/ANDALUCIA     1,93
# 3   Erakunde Autonomoa/CCAA                   ARAGOI/ARAGON     1,95
# 4   Erakunde Autonomoa/CCAA               ASTURIAS/ASTURIAS     2,14
# ..                      ...                             ...       ...
# 79  Erakunde Autonomoa/CCAA                ERRIOXA/LA RIOJA   2,08
# 80  Erakunde Autonomoa/CCAA  VALENTZIA KOMUNITATEA/VALENCIA   2,15
# 81           Lurraldea/TTHH                     ARABA/ÁLAVA   1,72
# 82           Lurraldea/TTHH                        GIPUZKOA   1,55
# 83           Lurraldea/TTHH                         BIZKAIA   1,45
#
#          Fecha             Tipo
# 0   2022-12-30  Tipo de Interes
# 1   2022-12-30  Tipo de Interes
# 2   2022-12-30  Tipo de Interes
# ...

# %%
df_tipo_interes_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Desglose    84 non-null     object
#  1   Territorio  84 non-null     object
#  2   T.Interes   84 non-null     object
#  3   Fecha       84 non-null     object
# dtypes: object(4)
# memory usage: 2.8+ KB

# %%
print(df_tipo_interes_2021)
# Out:
#                    Desglose                      Territorio T.Interes  \
# 0        Nazionala/Nacional                          ESPAÑA     1,92
# 1        Euskadi/País Vasco              EUSKADI/PAIS VASCO     1,48
# 2   Erakunde Autonomoa/CCAA             ANDALUZIA/ANDALUCIA     1,93
# 3   Erakunde Autonomoa/CCAA                   ARAGOI/ARAGON     1,95
# 4   Erakunde Autonomoa/CCAA               ASTURIAS/ASTURIAS     2,14
# ..                      ...                             ...       ...
# 79  Erakunde Autonomoa/CCAA                ERRIOXA/LA RIOJA   2,08
# 80  Erakunde Autonomoa/CCAA  VALENTZIA KOMUNITATEA/VALENCIA   2,15
# 81           Lurraldea/TTHH                     ARABA/ÁLAVA   1,72
# 82           Lurraldea/TTHH                        GIPUZKOA   1,55
# 83           Lurraldea/TTHH                         BIZKAIA   1,45
#
#          Fecha
# 0   2022-12-30
# 1   2022-12-30
# 2   2022-12-30
# 3   2022-12-30
# 4   2022-12-30
# ..         ...
# 79  2022-03-30
# ...

# %%
import pandas as pd
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2020.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-12-30')
df_precio_med_m2_2020_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2020_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2020.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-09-30')
df_precio_med_m2_2020_3 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2020_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2020.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-06-30')
df_precio_med_m2_2020_2 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2020_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2020.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2020-03-30')
df_precio_med_m2_2020_1 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2020_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2020_4, df_precio_med_m2_2020_3, df_precio_med_m2_2020_2, df_precio_med_m2_2020_1]  
df_precio_med_m2_2020 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2020.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio Viv. GENERAL  \
# 0                        Nazionala/Nacional               ESPAÑA    1.698,83
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO    2.847,66
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA    1.405,17
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON    1.446,14
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS    1.327,50
# ..                                      ...                  ...          ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05     2.183,99
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06     3.780,81
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07     2.449,40
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08     2.240,58
# 239                                     NaN                  NaN          NaN
#
# ...

# %%
import pandas as pd
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2019.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # PrD:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2020.2.csvimeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-12-30')
df_precio_med_m2_2019_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2019_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2019.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-09-30')
df_precio_med_m2_2019_3 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2019_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2019.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-06-30')
df_precio_med_m2_2019_2 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2019_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2019.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-03-30')
df_precio_med_m2_2019_1 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2019_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2019_4, df_precio_med_m2_2019_3, df_precio_med_m2_2019_2, df_precio_med_m2_2019_1]  
df_precio_med_m2_2019 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2019.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0        1.750,10      1.830,84      1.731,39  2019-12-30  Precio_Med_m2
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2018.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2018-12-30')
df_precio_med_m2_2018_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2018_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2018.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2019-09-30')
df_precio_med_m2_2018_3 = df.iloc[65:125] # primeras x filas
df_precio_med_m2_2018_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2018.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2018-06-30')
df_precio_med_m2_2018_2 = df.iloc[65:125] # primeras x filas
df_precio_med_m2_2018_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2018.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2018-03-30')
df_precio_med_m2_2018_1 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2018_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2018_4, df_precio_med_m2_2018_3, df_precio_med_m2_2018_2, df_precio_med_m2_2018_1]  
df_precio_med_m2_2018 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2018.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0     1.700,55      1.777,53      1.683,61     2018-12-30  Precio_Med_m2
# ...

# %%
df_precio_med_m2_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2017.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-12-30')
df_precio_med_m2_2017_4 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2017_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2017.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-09-30')
df_precio_med_m2_2017_3 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2017_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2017.2.csv',sep=';',encoding='latin-1',skiprows=2)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-06-30')
df_precio_med_m2_2017_2 = df.iloc[63:123] #primeras x filas
df_precio_med_m2_2017_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 63                       Nazionala/Nacional
# 64                       Euskadi/País Vasco
# 65                  Erakunde Autonomoa/CCAA
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81              Hiriburak/Capitales de TTHH
# 82              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2017.1.csv',sep=';',encoding='latin-1',skiprows=2)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2017-03-30')
df_precio_med_m2_2017_1 = df.iloc[63:123] #primeras x filas
df_precio_med_m2_2017_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 63                       Nazionala/Nacional
# 64                       Euskadi/País Vasco
# 65                  Erakunde Autonomoa/CCAA
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81              Hiriburak/Capitales de TTHH
# 82              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2017_4, df_precio_med_m2_2017_3, df_precio_med_m2_2017_2, df_precio_med_m2_2017_1]  
df_precio_med_m2_2017 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2017.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0     1.616,05      1.665,36      1.605,79     2017-12-30  Precio_Med_m2
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2016.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-12-30')
df_precio_med_m2_2016_4 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2016_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2016.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-09-30')
df_precio_med_m2_2016_3 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2016_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2016.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-06-30')
df_precio_med_m2_2016_2 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2016_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2016.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2016-03-30')
df_precio_med_m2_2016_1 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2016_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2016_4, df_precio_med_m2_2016_3, df_precio_med_m2_2016_2, df_precio_med_m2_2016_1]  
df_precio_med_m2_2016 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2016.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0     1.541,45      1.582,57      1.533,04     2016-12-30  Precio_Med_m2
# ...

# %%
df_precio_med_m2_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2015.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-12-30')
df_precio_med_m2_2015_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2015_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2015.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-09-30')
df_precio_med_m2_2015_3 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2015_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2015.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-06-30')
df_precio_med_m2_2015_2 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2015_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2015.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2015-03-30')
df_precio_med_m2_2015_1 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2015_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2015_4, df_precio_med_m2_2015_3, df_precio_med_m2_2015_2, df_precio_med_m2_2015_1]  
df_precio_med_m2_2015 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2015.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL Viv. NUEVA Viv. USADA       Fecha           Tipo
# 0        1.482,03   1.536,35   1.469,56  2015-12-30  Precio_Med_m2
# ...

# %%
df_precio_med_m2_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2014.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-12-30')
df_precio_med_m2_2014_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2014_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2014.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-12-30')
df_precio_med_m2_2014_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2014_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                       Nazionala/Nacional
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2014.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-09-30')
df_precio_med_m2_2014_3 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2014_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                        Estatukoa/Estatal
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2014.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-06-30')
df_precio_med_m2_2014_2 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2014_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                        Estatukoa/Estatal
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2014.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2014-03-30')
df_precio_med_m2_2014_1 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2014_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 64                        Estatukoa/Estatal
# 65                       Euskadi/País Vasco
# 66                  Erakunde Autonomoa/CCAA
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82              Hiriburak/Capitales de TTHH
# 83              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2014_4, df_precio_med_m2_2014_3, df_precio_med_m2_2014_2, df_precio_med_m2_2014_1]  
df_precio_med_m2_2014 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2014.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0     1.412,96      1.366,95      1.432,44     2014-12-30  Precio_Med_m2
# ...

# %%
df_precio_med_m2_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2013.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-12-30')
df_precio_med_m2_2013_4 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2013_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2013.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-09-30')
df_precio_med_m2_2013_3 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2013_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2013.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-06-30')
df_precio_med_m2_2013_2 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2013_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2013.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2013-03-30')
df_precio_med_m2_2013_1 = df.iloc[65:125] #primeras x filas
df_precio_med_m2_2013_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose  \
# 65                       Nazionala/Nacional
# 66                       Euskadi/País Vasco
# 67                  Erakunde Autonomoa/CCAA
# 68                  Erakunde Autonomoa/CCAA
# 69                  Erakunde Autonomoa/CCAA
# 70                  Erakunde Autonomoa/CCAA
# 71                  Erakunde Autonomoa/CCAA
# 72                  Erakunde Autonomoa/CCAA
# 73                  Erakunde Autonomoa/CCAA
# 74                  Erakunde Autonomoa/CCAA
# 75                  Erakunde Autonomoa/CCAA
# 76                  Erakunde Autonomoa/CCAA
# 77                  Erakunde Autonomoa/CCAA
# 78                  Erakunde Autonomoa/CCAA
# 79                  Erakunde Autonomoa/CCAA
# 80                  Erakunde Autonomoa/CCAA
# 81                  Erakunde Autonomoa/CCAA
# 82                  Erakunde Autonomoa/CCAA
# 83              Hiriburak/Capitales de TTHH
# 84              Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2013_4, df_precio_med_m2_2013_3, df_precio_med_m2_2013_2, df_precio_med_m2_2013_1]  
df_precio_med_m2_2013 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2013.assign(Tipo='Precio_Med_m2')
# Out:
#                                    Desglose           Territorio  \
# 0                        Nazionala/Nacional               ESPAÑA
# 1                        Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                   Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                   Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                   Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                      ...                  ...
# 235  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak/Zonas de capitales       Bilbao zona 08
# 239                                     NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0     1.400,16      1.371,94      1.422,93     2013-12-30  Precio_Med_m2
# ...

# %%
df_precio_med_m2_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2012.4.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-12-30')
df_precio_med_m2_2012_4 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2012_4.assign(Tipo='Precio_Med_m2')
# Out:
#                                           Desglose  \
# 64                              Nazionala/Nacional
# 65                              Euskadi/País Vasco
# 66                         Erakunde Autonomoa/CCAA
# 67                         Erakunde Autonomoa/CCAA
# 68                         Erakunde Autonomoa/CCAA
# 69                         Erakunde Autonomoa/CCAA
# 70                         Erakunde Autonomoa/CCAA
# 71                         Erakunde Autonomoa/CCAA
# 72                         Erakunde Autonomoa/CCAA
# 73                         Erakunde Autonomoa/CCAA
# 74                         Erakunde Autonomoa/CCAA
# 75                         Erakunde Autonomoa/CCAA
# 76                         Erakunde Autonomoa/CCAA
# 77                         Erakunde Autonomoa/CCAA
# 78                         Erakunde Autonomoa/CCAA
# 79                         Erakunde Autonomoa/CCAA
# 80                         Erakunde Autonomoa/CCAA
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2012.3.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-09-30')
df_precio_med_m2_2012_3 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2012_3.assign(Tipo='Precio_Med_m2')
# Out:
#                                           Desglose  \
# 64                              Nazionala/Nacional
# 65                              Euskadi/País Vasco
# 66                         Erakunde Autonomoa/CCAA
# 67                         Erakunde Autonomoa/CCAA
# 68                         Erakunde Autonomoa/CCAA
# 69                         Erakunde Autonomoa/CCAA
# 70                         Erakunde Autonomoa/CCAA
# 71                         Erakunde Autonomoa/CCAA
# 72                         Erakunde Autonomoa/CCAA
# 73                         Erakunde Autonomoa/CCAA
# 74                         Erakunde Autonomoa/CCAA
# 75                         Erakunde Autonomoa/CCAA
# 76                         Erakunde Autonomoa/CCAA
# 77                         Erakunde Autonomoa/CCAA
# 78                         Erakunde Autonomoa/CCAA
# 79                         Erakunde Autonomoa/CCAA
# 80                         Erakunde Autonomoa/CCAA
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2012.2.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-06-30')
df_precio_med_m2_2012_2 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2012_2.assign(Tipo='Precio_Med_m2')
# Out:
#                                           Desglose  \
# 64                              Nazionala/Nacional
# 65                              Euskadi/País Vasco
# 66                         Erakunde Autonomoa/CCAA
# 67                         Erakunde Autonomoa/CCAA
# 68                         Erakunde Autonomoa/CCAA
# 69                         Erakunde Autonomoa/CCAA
# 70                         Erakunde Autonomoa/CCAA
# 71                         Erakunde Autonomoa/CCAA
# 72                         Erakunde Autonomoa/CCAA
# 73                         Erakunde Autonomoa/CCAA
# 74                         Erakunde Autonomoa/CCAA
# 75                         Erakunde Autonomoa/CCAA
# 76                         Erakunde Autonomoa/CCAA
# 77                         Erakunde Autonomoa/CCAA
# 78                         Erakunde Autonomoa/CCAA
# 79                         Erakunde Autonomoa/CCAA
# 80                         Erakunde Autonomoa/CCAA
# ...

# %%
df = pd.read_csv('D:/PERSONAL-DAS/BOOTCAMP/Ejercicios/Proyectos/2-EDA/00/2012.1.csv',sep=';',encoding='latin-1',skiprows=3)
df= df.iloc[:, 0:5] # Primeras x columnas
df = df.rename(columns={'BANATZEA                                        DESGLOSE':'Desglose','EREMUA                                                    ÁMBITO':'Territorio'})
df = df.rename(columns={'OROKORRA GENERAL': "Viv. GENERAL",'BERRIA NUEVA': 'Viv. NUEVA','ERABILIA USADA':'Viv. USADA'})
df = df.assign(Fecha='2012-03-30')
df_precio_med_m2_2012_1 = df.iloc[64:124] #primeras x filas
df_precio_med_m2_2012_1.assign(Tipo='Precio_Med_m2')
# Out:
#                                     Desglose  \
# 64                        Nazionala/Nacional
# 65                        Euskadi/País Vasco
# 66                   Erakunde Autonomoa/CCAA
# 67                   Erakunde Autonomoa/CCAA
# 68                   Erakunde Autonomoa/CCAA
# 69                   Erakunde Autonomoa/CCAA
# 70                   Erakunde Autonomoa/CCAA
# 71                   Erakunde Autonomoa/CCAA
# 72                   Erakunde Autonomoa/CCAA
# 73                   Erakunde Autonomoa/CCAA
# 74                   Erakunde Autonomoa/CCAA
# 75                   Erakunde Autonomoa/CCAA
# 76                   Erakunde Autonomoa/CCAA
# 77                   Erakunde Autonomoa/CCAA
# 78                   Erakunde Autonomoa/CCAA
# 79                   Erakunde Autonomoa/CCAA
# 80                   Erakunde Autonomoa/CCAA
# 81                   Erakunde Autonomoa/CCAA
# 82               Hiriburak/Capitales de TTHH
# 83               Hiriburak/Capitales de TTHH
# ...

# %%
frames = [df_precio_med_m2_2012_4, df_precio_med_m2_2012_3, df_precio_med_m2_2012_2, df_precio_med_m2_2012_1]  
df_precio_med_m2_2012 = pd.concat(frames, ignore_index=True)
df_precio_med_m2_2012.assign(Tipo='Precio_Med_m2')
# Out:
#                                     Desglose           Territorio  \
# 0                         Nazionala/Nacional               ESPAÑA
# 1                         Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                    Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                    Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                    Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ..                                       ...                  ...
# 235  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 236  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 237  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 238  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
# 239                                      NaN                  NaN
#
#      Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha           Tipo
# 0     1.487,38      1.500,62      1.474,46     2012-12-30  Precio_Med_m2
# ...

# %%
df_precio_med_m2_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      236 non-null    object
#  1   Territorio    236 non-null    object
#  2   Viv. GENERAL  236 non-null    object
#  3   Viv. NUEVA    236 non-null    object
#  4   Viv. USADA    236 non-null    object
#  5   Fecha         240 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
frames = [df_precio_med_m2_2023, df_precio_med_m2_2022, df_precio_med_m2_2021, df_precio_med_m2_2020, df_precio_med_m2_2019, df_precio_med_m2_2018, df_precio_med_m2_2017, df_precio_med_m2_2016, df_precio_med_m2_2015, df_precio_med_m2_2014, df_precio_med_m2_2013, df_precio_med_m2_2012]  
df_precio_med_m2 = pd.concat(frames, ignore_index=True)
df_precio_med_m2.assign(Tipo='Precio_Med_m2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\PERSONAL-DAS\BOOTCAMP\Carpeta-VISUAL\CURSO\Alumno-DAS\2-Data_Analysis\Z-Entregas\2_EDA\ER-mydt-Tipo Interes.ipynb Cell 69 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/PERSONAL-DAS/BOOTCAMP/Carpeta-VISUAL/CURSO/Alumno-DAS/2-Data_Analysis/Z-Entregas/2_EDA/ER-mydt-Tipo%20Interes.ipynb#Y125sZmlsZQ%3D%3D?line=0'>1</a> frames = [df_precio_med_m2_2023, df_precio_med_m2_2022, df_precio_med_m2_2021, df_precio_med_m2_2020, df_precio_med_m2_2019, df_precio_med_m2_2018, df_precio_med_m2_2017, df_precio_med_m2_2016, df_precio_med_m2_2015, df_precio_med_m2_2014, df_precio_med_m2_2013, df_precio_med_m2_2012]
# ...

# %%
df_precio_med_m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Desglose      2784 non-null   object
#  1   Territorio    2784 non-null   object
#  2   Viv. GENERAL  2784 non-null   object
#  3   Viv. NUEVA    2784 non-null   object
#  4   Viv. USADA    2784 non-null   object
#  5   Fecha         2830 non-null   object
# dtypes: object(6)
# memory usage: 132.8+ KB

# %%
df_precio_med_m2.shape
# Out:
# (2830, 6)

# %%
print(df_precio_med_m2.isnull().sum()) # verificar si esta limpio
# Out:
# Desglose        46
# Territorio      46
# Viv. GENERAL    46
# Viv. NUEVA      46
# Viv. USADA      46
# Fecha            0
# dtype: int64

# %%
df_precio_med_m2.dtypes
# Out:
# Desglose        object
# Territorio      object
# Viv. GENERAL    object
# Viv. NUEVA      object
# Viv. USADA      object
# Fecha           object
# dtype: object

# %%
df_precio_med_m2.dropna(axis='rows', how='all') # suprimo los elemento de filas con todo nulos
# Out:
#                                      Desglose           Territorio  \
# 0                          Nazionala/Nacional               ESPAÑA
# 1                          Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                     Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                     Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                     Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ...                                       ...                  ...
# 2825  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 2826  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 2827  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 2828  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
# 2829                                      NaN                  NaN
#
#       Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha
# 0          1979,48       2212,37        1924,6  2023-06-30
# ...

# %%
df_precio_med_m2.dropna(axis='columns', how='all') # suprimo los elemento de filas con todo nulos
# Out:
#                                      Desglose           Territorio  \
# 0                          Nazionala/Nacional               ESPAÑA
# 1                          Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                     Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                     Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                     Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ...                                       ...                  ...
# 2825  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 2826  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 2827  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 2828  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
# 2829                                      NaN                  NaN
#
#       Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha
# 0          1979,48       2212,37        1924,6  2023-06-30
# ...

# %%
print(df_precio_med_m2.isnull().sum()) # verificar si esta limpio
# Out:
# Desglose        46
# Territorio      46
# Viv. GENERAL    46
# Viv. NUEVA      46
# Viv. USADA      46
# Fecha            0
# dtype: int64

# %%
columns_with_nulls = df_precio_med_m2.columns[df_precio_med_m2.isnull().any()]
columns_with_nulls
# Out:
# Index(['Desglose', 'Territorio', 'Viv. GENERAL', 'Viv. NUEVA', 'Viv. USADA'], dtype='object')

# %%
print(df_precio_med_m2.isnull())
# Out:
#       Desglose  Territorio  Viv. GENERAL  Viv. NUEVA  Viv. USADA  Fecha
# 0        False       False         False       False       False  False
# 1        False       False         False       False       False  False
# 2        False       False         False       False       False  False
# 3        False       False         False       False       False  False
# 4        False       False         False       False       False  False
# ...        ...         ...           ...         ...         ...    ...
# 2825     False       False         False       False       False  False
# 2826     False       False         False       False       False  False
# 2827     False       False         False       False       False  False
# 2828     False       False         False       False       False  False
# 2829      True        True          True        True        True  False
#
# [2830 rows x 6 columns]

# %%
df_precio_med_m2.dropna(axis='rows', thresh=len(df_precio_med_m2.columns)*0.75)
# Out:
#                                      Desglose           Territorio  \
# 0                          Nazionala/Nacional               ESPAÑA
# 1                          Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                     Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                     Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                     Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ...                                       ...                  ...
# 2824  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 04
# 2825  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 2826  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 2827  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 2828  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
#
#       Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha
# 0          1979,48       2212,37        1924,6  2023-06-30
# ...

# %%
print(df_precio_med_m2.isnull().sum()) # verificar si esta limpio
# Out:
# Desglose        46
# Territorio      46
# Viv. GENERAL    46
# Viv. NUEVA      46
# Viv. USADA      46
# Fecha            0
# dtype: int64

# %%
df_precio_med_m2.dropna(axis='columns', thresh=len(df_precio_med_m2.columns)*0.75)
# Out:
#                                      Desglose           Territorio  \
# 0                          Nazionala/Nacional               ESPAÑA
# 1                          Euskadi/País Vasco   EUSKADI/PAIS VASCO
# 2                     Erakunde Autonomoa/CCAA  ANDALUZIA/ANDALUCIA
# 3                     Erakunde Autonomoa/CCAA        ARAGOI/ARAGON
# 4                     Erakunde Autonomoa/CCAA    ASTURIAS/ASTURIAS
# ...                                       ...                  ...
# 2825  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 05
# 2826  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 06
# 2827  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 07
# 2828  Hiriburuetako zonak /Zonas de capitales       Bilbao zona 08
# 2829                                      NaN                  NaN
#
#       Viv. GENERAL    Viv. NUEVA    Viv. USADA       Fecha
# 0          1979,48       2212,37        1924,6  2023-06-30
# ...

# %%
print(df_precio_med_m2.isnull().sum()) # verificar si esta limpio
# Out:
# Desglose        46
# Territorio      46
# Viv. GENERAL    46
# Viv. NUEVA      46
# Viv. USADA      46
# Fecha            0
# dtype: int64

# %%
print(df_precio_med_m2['Desglose'].isnull)
# Out:
# <bound method Series.isnull of 0                            Nazionala/Nacional
# 1                            Euskadi/País Vasco
# 2                       Erakunde Autonomoa/CCAA
# 3                       Erakunde Autonomoa/CCAA
# 4                       Erakunde Autonomoa/CCAA
#                          ...
# 2825    Hiriburuetako zonak /Zonas de capitales
# 2826    Hiriburuetako zonak /Zonas de capitales
# 2827    Hiriburuetako zonak /Zonas de capitales
# 2828    Hiriburuetako zonak /Zonas de capitales
# 2829                                        NaN
# Name: Desglose, Length: 2830, dtype: object>

# %%
df_precio_med_m2.groupby['']
